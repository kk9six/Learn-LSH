# %%
import numpy as np
import matplotlib.pyplot as plt
import math

# %% [markdown]
# # 固定维度

# %%
D = np.array([4, 6, 7, 8, 9, 10])

# %% [markdown]
# ## 计算最近邻时间

# %%
nearest_time1 = [3.5, 8.9, 19.8, 24, 34.4, 52]
nearest_time2 = [8.5, 14.1, 24.9, 28.3, 37, 50]
nearest_time3 = [33, 33, 36, 52.9, 71.56, 81.54]
nearest_time4 = [13.5, 20, 25, 36, 47, 55]
nearest_time5 = [39.51, 42, 52.4, 59, 75, 87]
linear_time = [107, 114, 121, 130, 140, 160]

# %%
# %matplotlib inline

# %%
plt.figure(figsize=(5, 4))
plt.plot(D, nearest_time1, c='r', marker='o', label='OPRCP', )
plt.plot(D, nearest_time2, c='tomato', marker='x', label='TLOPRCP')
plt.plot(D, nearest_time3, c='grey', marker='>', label='TLE2LSH', linestyle='dashed')
plt.plot(D, nearest_time4, c='slategrey', marker='d', label='TLBHL', linestyle='dashed')
plt.plot(D, nearest_time5, c='dimgrey', marker='D', label='BHL', linestyle='dashed')
plt.plot(D, linear_time, c='b', marker='v', label='linear search', linestyle='dashed')
plt.legend(fontsize=12)
plt.subplots_adjust(top=0.950,
bottom=0.135,
left=0.15,
right=0.95,
hspace=0.2,
wspace=0.2)
plt.xticks(D, fontsize=12)
plt.yticks(fontsize=12)
plt.xlabel('K (2^K dim)', fontsize=14)
plt.ylabel('find nearest time(ms)', fontsize=14)
plt.grid()
plt.savefig('./img/nearest_time.png', dpi=1500) # , papertype='letter'

# %% [markdown]
# ## 计算时间

# %%
times1 = [2.0, 2.8, 6.6, 7, 15.7, 22.3]
times2 = [3.2, 3.2, 8, 8.7, 14.5, 26]
times3 = [33.7, 28.04, 30, 42.13, 57, 64.5]
times4 = [4.6, 10, 12, 17, 33, 38]
times5 = [38.72, 37.93, 40, 52, 59, 63]

# %%
plt.figure(figsize=(5, 4))
plt.plot(D, times1, c='r', marker='o', label='OPRCP', )
plt.plot(D, times2, c='tomato', marker='x', label='TLOPRCP')
plt.plot(D, times3, c='grey', marker='>', label='TLE2LSH', linestyle='dashed')
plt.plot(D, times4, c='slategrey', marker='d', label='TLBHL', linestyle='dashed')
plt.plot(D, times5, c='dimgrey', marker='D', label='BHL', linestyle='dashed')
plt.plot(D, linear_time, c='b', marker='v', label='linear search', linestyle='dashed')

plt.subplots_adjust(top=0.950,
bottom=0.135,
left=0.15,
right=0.95,
hspace=0.2,
wspace=0.2)
plt.xlabel('K (2^K dim)', fontsize=14)
plt.ylabel('hashing time(ms)', fontsize=14)
plt.legend(fontsize=12)
plt.xticks(D, fontsize=12)
plt.yticks(fontsize=12)
plt.grid()
plt.savefig('./img/d-time.png', dpi=1500)

# %% [markdown]
# ## 候选集

# %%
candidate1 = np.array([156, 412, 554, 635, 706, 716]) / 1e4
candidate2 = np.array([388, 733, 720, 757, 727, 804]) / 1e4
candidate3 = np.array([150, 364, 467, 700, 756, 835]) / 1e4
candidate4 = np.array([653, 764, 926, 1098, 729, 873]) / 1e4
candidate5 = np.array([74, 272, 351, 481, 671, 731]) / 1e4

# %%
plt.figure(figsize=(5, 4))
plt.plot(D, candidate1, c='r', marker='o', label='OPRCP', )
plt.plot(D, candidate2, c='tomato', marker='x', label='TLOPRCP')
plt.plot(D, candidate3, c='grey', marker='>', label='TLE2LSH', linestyle='dashed')
plt.plot(D, candidate4, c='slategrey', marker='d', label='TLBHL', linestyle='dashed')
plt.plot(D, candidate5, c='dimgrey', marker='D', label='BHL', linestyle='dashed')

plt.subplots_adjust(top=0.950,
bottom=0.135,
left=0.15,
right=0.95,
hspace=0.2,
wspace=0.2)
plt.xlabel('K (2^K dim)', fontsize=14)
plt.ylabel('candidate / n', fontsize=14)
plt.legend(fontsize=12)
plt.xticks(D, fontsize=12)
plt.yticks(fontsize=12)
plt.grid()
plt.savefig('./img/d-candidate.png', dpi=1500)

# %% [markdown]
# ## 准确度

# %%
accs1 = [0.55, 0.759, 0.93, 0.96, 0.99, 0.99]
accs2 = [0.4497, 0.6917, 0.8873, 0.95, 0.99, 0.99]
accs3 = [0.3887, 0.7545, 0.9, 0.8684, 0.97, 0.97]
accs4 = [0.32, 0.64, 0.82, 0.75, 0.99, 0.99]
accs5 = [0.6417, 0.8397, 0.94, 0.94, 0.96, 0.97]

# %%
plt.figure(figsize=(5, 4))
plt.plot(D, accs1, c='r', marker='o', label='OPRCP', )
plt.plot(D, accs2, c='tomato', marker='x', label='TLOPRCP')
plt.plot(D, accs3, c='grey', marker='>', label='TLE2LSH', linestyle='dashed')
plt.plot(D, accs4, c='slategrey', marker='d', label='TLBHL', linestyle='dashed')
plt.plot(D, accs5, c='dimgrey', marker='D', label='BHL', linestyle='dashed')

plt.subplots_adjust(top=0.950,
bottom=0.135,
left=0.15,
right=0.95,
hspace=0.2,
wspace=0.2)
plt.xlabel('K (2^K dim)', fontsize=14)
plt.ylabel('precision', fontsize=14)
plt.legend(fontsize=12)
plt.xticks(D, fontsize=12)
plt.yticks(fontsize=12)
plt.grid()
plt.savefig('./img/d-precision.png', dpi=1500)

# %% [markdown]
# ## 召回率

# %%
recalls1 = [0.1937, 0.429, 0.585, 0.678, 0.7809, 0.79]
recalls2 = [0.3857, 0.7049, 0.7167, 0.8, 0.8, 0.89]
recalls3 = [0.1454, 0.3852, 0.4725, 0.6250, 0.785, 0.8685]
recalls4 = [0.47, 0.69, 0.84, 0.91, 0.80, 0.96]
recalls5 = [0.13, 0.32, 0.373, 0.5042, 0.7201, 0.781]

# %%
plt.figure(figsize=(5, 4))
plt.plot(D, recalls1, c='r', marker='o', label='OPRCP', )
plt.plot(D, recalls2, c='tomato', marker='x', label='TLOPRCP')
plt.plot(D, recalls3, c='grey', marker='>', label='TLE2LSH', linestyle='dashed')
plt.plot(D, recalls4, c='slategrey', marker='d', label='TLBHL', linestyle='dashed')
plt.plot(D, recalls5, c='dimgrey', marker='D', label='BHL', linestyle='dashed')

plt.subplots_adjust(top=0.950,
bottom=0.135,
left=0.15,
right=0.95,
hspace=0.2,
wspace=0.2)
plt.xlabel('K (2^K dim)', fontsize=14)
plt.ylabel('recall', fontsize=14)
plt.legend(fontsize=12)
plt.xticks(D, fontsize=12)
plt.yticks(fontsize=12)
plt.grid()
plt.savefig('./img/d-recall.png', dpi=1500)

# %% [markdown]
# ## F1 值

# %%
F11 = [0.2874, 0.5485, 0.7210, 0.7939, 0.8739, 0.8834]
F12 = [0.4153, 0.6982, 0.7930, 0.8696, 0.8523, 0.9402]
F13 = [0.2070, 0.51, 0.62, 0.7596, 0.8523, 0.9023]
F14 = [0.38, 0.66, 0.83, 0.83, 0.89, 0.95]
F15 = [0.2185, 0.4634, 0.5352, 0.6565, 0.8237, 0.8716]

# %%
plt.figure(figsize=(5, 4))
plt.plot(D, F11, c='r', marker='o', label='OPRCP', )
plt.plot(D, F12, c='tomato', marker='x', label='TLOPRCP')
plt.plot(D, F13, c='grey', marker='>', label='TLE2LSH', linestyle='dashed')
plt.plot(D, F14, c='slategrey', marker='d', label='TLBHL', linestyle='dashed')
plt.plot(D, F15, c='dimgrey', marker='D', label='BHL', linestyle='dashed')

plt.subplots_adjust(top=0.950,
bottom=0.135,
left=0.15,
right=0.95,
hspace=0.2,
wspace=0.2)
plt.xlabel('K (2^K dim)', fontsize=14)
plt.ylabel('F1', fontsize=14)
plt.legend(fontsize=12)
plt.xticks(D, fontsize=12)
plt.yticks(fontsize=12)
plt.grid()
plt.savefig('./img/d-F1.png', dpi=1500)

# %% [markdown]
# ## 存储消耗

# %%
mems1 = [8.34, 22, 28.31, 65.99, 64.456, 64]
mems2 = [2.06, 2.22, 2.435, 3.0887, 3.7465, 3.4]
mems3 = [278, 300, 295, 384, 473, 524]
mems4 = [7, 30, 38, 55, 99, 140]
mems5 = [416, 368, 371, 457, 389, 374]

# %%
plt.figure(figsize=(5, 4))
plt.plot(D, mems1, c='r', marker='o', label='OPRCP', )
plt.plot(D, mems2, c='tomato', marker='x', label='TLOPRCP')
plt.plot(D, mems3, c='grey', marker='>', label='TLE2LSH', linestyle='dashed')
plt.plot(D, mems4, c='slategrey', marker='d', label='TLBHL', linestyle='dashed')
plt.plot(D, mems5, c='dimgrey', marker='D', label='BHL', linestyle='dashed')

plt.subplots_adjust(top=0.950,
bottom=0.135,
left=0.15,
right=0.95,
hspace=0.2,
wspace=0.2)
plt.xlabel('K (2^K dim)', fontsize=14)
plt.ylabel('memory (MB)', fontsize=14)
plt.legend(fontsize=12)
plt.xticks(D, fontsize=12)
plt.yticks(fontsize=12)
plt.grid()
plt.savefig('./img/d-memory.png', dpi=1500)

# %% [markdown]
# # 参数

# %% [markdown]
# L: 10
#
# d: 128
#
# n: 1e4
#
# k: 2

# %%
# %matplotlib
# Out:
# Using matplotlib backend: Qt5Agg

# %% [markdown]
# ## k = 2, L = 10, m from 1 to 8

# %%
M = [1, 2, 3, 4, 5, 6, 7, 8]
precision = [0.71, 0.88, 0.91, 0.94, 0.98, 0.98, 0.98, 1]
std_precision = [0.797, 0.7482, 0.7054, 0.66, 0.63, 0.6, 0.57, 0.55]
recall = [0.4573, 0.5946, 0.6791, 0.73, 0.767, 0.79, 0.81, 0.84]
f1 = [0.5812, 0.6625, 0.693, 0.6959, 0.6948, 0.68, 0.67, 0.66]
time = [6, 6, 7, 9, 10.8, 12, 13, 15.21]
nearest_time = [16, 20, 28, 30, 36, 38, 45, 47.36]
candidate = [522, 726, 884, 1014, 1106, 1200, 1296, 1392]

# %% [markdown]
# ### 找到最近邻的概率和 m 的关系

# %%
# %matplotlib inline

# %%
plt.figure(figsize=(5, 4))

# plt.rc('font', family='Cantarell', serif='Times')
# plt.rc('text', usetex=True)
# plt.rc('xtick', labelsize=13)
# plt.rc('ytick', labelsize=13)
# plt.rc('axes', labelsize=13)

plt.plot(M, precision, marker='o', c='r')

plt.grid()
plt.annotate('Pr(find the nearest neighbor)',
             xy=(M[4],precision[4]), xycoords = 'data', xytext= (-120,+10),
             textcoords= 'offset points',
             fontsize = 12,
             arrowprops = dict(arrowstyle = '->',connectionstyle = 'arc3,rad = .2'))

plt.xticks(M, fontsize=12)
plt.yticks(fontsize=12)
plt.ylabel('Pr(find the nearest neighbor)', fontsize=12)
plt.xlabel('m (probe factor)', fontsize=12)


plt.twinx()
plt.plot(M, recall, marker='v', linestyle='dashed', c='darkblue', label='recall')
plt.plot(M, f1, marker='>', label='F1', c='b',  linestyle='dashed')
plt.plot(M, std_precision, linestyle='dashed', marker='x', c='dodgerblue', label='precision')

plt.yticks(fontsize=12)
plt.ylabel('precision \ recall \ F1', fontsize=12)
plt.legend(fontsize=12)

plt.subplots_adjust(top=0.950,
bottom=0.135,
left=0.18,
right=0.85,
hspace=0.2,
wspace=0.2)
plt.savefig('./img/k=2-L=10-1.png',dpi=1500)
plt.show()

# %% [markdown]
# ### 候选集和m的关系，以及和其他指标的关系

# %%
plt.figure(figsize=(5, 4))

plt.plot(M, candidate, marker='o', c='r')
plt.grid()
plt.annotate('number of candidates',
             xy=(M[4],candidate[4]), xycoords = 'data', xytext= (-100,+50),
             textcoords= 'offset points',
             fontsize = 12,
             arrowprops = dict(arrowstyle = '->',connectionstyle = 'arc3,rad = .2'))

plt.xticks(M, fontsize=12)
plt.yticks(fontsize=10)
plt.xlabel('m', fontsize=12)
plt.ylabel('number of candidates', fontsize=12)


plt.twinx()
plt.plot(M, recall, marker='v', linestyle='dashed', c='darkblue', label='recall')
plt.plot(M, f1, marker='>', label='F1', c='b',  linestyle='dashed')
plt.plot(M, std_precision, linestyle='dashed', marker='x', c='dodgerblue', label='precision')

plt.yticks(fontsize=12)
plt.ylabel('precision \ recall \ F1', fontsize=12)
plt.legend(fontsize=12)

plt.subplots_adjust(top=0.950,
bottom=0.135,
left=0.18,
right=0.85,
hspace=0.2,
wspace=0.2)
plt.savefig('./img/k=2-L=10-2.png',dpi=1500)
plt.show()

# %% [markdown]
# ### 找到最近邻的概率和查询时间的关系

# %%
plt.figure(figsize=(5, 4))

plt.plot(M, precision, marker='o', c='r')
plt.grid()
plt.annotate('Pr(find the nearest neighbor)',
             xy=(M[4],precision[4]), xycoords = 'data', xytext= (-120,+10),
             textcoords= 'offset points',
             fontsize = 12,
             arrowprops = dict(arrowstyle = '->',connectionstyle = 'arc3,rad = .2'))

plt.xticks(M, fontsize=12)
plt.yticks(fontsize=12)
plt.xlabel('m', fontsize=12)
plt.ylabel('Pr(find the nearest neighbor)', fontsize=12)



plt.twinx()
plt.plot(M, nearest_time, marker='>', c='b',  linestyle='dashed', label='total query time',)
plt.plot(M, time, marker='v', c='darkblue', linestyle='dashed', label='hashing time')
# plt.plot(M, std_precision,  marker='x', c='dodgerblue', linestyle='dashed', label='precision')

plt.yticks(fontsize=12)
plt.ylabel('time(ms)', fontsize=12)
plt.legend(loc=7, fontsize=12)

plt.subplots_adjust(top=0.950,
bottom=0.135,
left=0.18,
right=0.85,
hspace=0.2,
wspace=0.2)
plt.savefig('./img/k=2-L=10-3.png',dpi=1500)
plt.show()

# %% [markdown]
# ### 候选集和查询时间的关系

# %%
plt.figure(figsize=(5, 4))

plt.plot(M, candidate, marker='o', c='r')
plt.grid()
plt.annotate('number of candidates',
             xy=(M[4],candidate[4]), xycoords = 'data', xytext= (-140,+10),
             textcoords= 'offset points',
             fontsize = 11,
             arrowprops = dict(arrowstyle = '->',connectionstyle = 'arc3,rad = .2'))


plt.xticks(M, fontsize=12)
plt.yticks(fontsize=12)
plt.xlabel('m', fontsize=12)
plt.ylabel('number of candidates', fontsize=12)

plt.twinx()
plt.plot(M, nearest_time, marker='>', c='b',  linestyle='dashed', label='total query time',)
plt.plot(M, time, marker='v', c='darkblue', linestyle='dashed', label='hashing time')
# plt.plot(M, std_precision,  marker='x', c='dodgerblue', linestyle='dashed', label='precision')

plt.yticks(fontsize=12)
plt.ylabel('time(ms)', fontsize=12)
plt.legend(loc=7, fontsize=12)

plt.subplots_adjust(top=0.950,
bottom=0.135,
left=0.18,
right=0.85,
hspace=0.2,
wspace=0.2)
plt.savefig('./img/k=2-L=10-4.png',dpi=1500)
plt.show()

# %% [markdown]
# ## m = 1, k = 2, L = [10, 20, 30, 40, 50]

# %%
L = [10, 20, 30, 40, 50]
precision = [0.71, 0.88, 0.98, 1, 1]
std_precision = [0.797, 0.76, 0.758, 0.6817, 0.7]
recall = [0.4573, 0.63, 0.838, 0.88, 0.92]
f1 = [0.5812, 0.69, 0.796, 0.77, 0.79]
time = [6, 9, 13.4, 17, 22]
nearest_time = [16, 28, 36, 40, 54]
candidate = [522, 744, 997, 1193, 1200]
mem = [2.58, 3.4, 5, 7.2, 9.9, 12]

# %%
plt.figure(figsize=(5, 4))
plt.plot(L, precision, marker='o', c='r')
plt.grid()
plt.annotate('Pr(find the nearest neighbor)',
             xy=(L[2], precision[2]), xycoords = 'data', xytext= (-120,+10),
             textcoords= 'offset points',
             fontsize = 12,
             arrowprops = dict(arrowstyle = '->',connectionstyle = 'arc3,rad = .2'))

plt.xticks(L, fontsize=12)
plt.yticks(fontsize=12)
plt.xlabel('L(number of hash tables)', fontsize=12)
plt.ylabel('Pr(find the nearest neighbor)', fontsize=12)

plt.twinx()
plt.plot(L, recall, marker='v', linestyle='dashed', c='darkblue', label='recall')
plt.plot(L, f1, marker='>', label='F1', c='b',  linestyle='dashed')
plt.plot(L, std_precision, linestyle='dashed', marker='x', c='dodgerblue', label='precision')

plt.yticks(fontsize=12)
plt.ylabel('precision \ recall \ F1', fontsize=12)
plt.legend(loc=4, fontsize=12)

plt.subplots_adjust(top=0.950,
bottom=0.135,
left=0.18,
right=0.85,
hspace=0.2,
wspace=0.2)
plt.savefig('./img/k=2-m=1-1.png',dpi=1500)
plt.show()

# %%
plt.figure(figsize=(5, 4))
plt.plot(L, candidate, marker='o', c='r')
plt.grid()
plt.annotate('number of candidates',
             xy=(L[1],candidate[1]), xycoords = 'data', xytext= (+30,+0),
             textcoords= 'offset points',
             fontsize = 12,
             arrowprops = dict(arrowstyle = '->',connectionstyle = 'arc3,rad = .2'))


plt.xticks(L, fontsize=12)
plt.yticks(fontsize=12)
plt.xlabel('L', fontsize=12)
plt.ylabel('number of candidates', fontsize=12)

plt.twinx()
plt.plot(L, recall, marker='v', linestyle='dashed', c='darkblue', label='recall')
plt.plot(L, f1, marker='>', label='F1', c='b',  linestyle='dashed')
plt.plot(L, std_precision, linestyle='dashed', marker='x', c='dodgerblue', label='precision')

plt.yticks(fontsize=12)
plt.ylabel('precision \ recall \ F1', fontsize=12)
plt.legend(loc=4, fontsize=12)

plt.subplots_adjust(top=0.950,
bottom=0.135,
left=0.18,
right=0.85,
hspace=0.2,
wspace=0.2)
plt.savefig('./img/k=2-m=1-2.png',dpi=1500)
plt.show()

# %%
plt.figure(figsize=(5, 4))
plt.plot(L, precision, marker='o', c='r')
plt.grid()
plt.annotate('Pr(find the nearest neighbor)',
             xy=(L[2],precision[2]), xycoords = 'data', xytext= (-120,+10),
             textcoords= 'offset points',
             fontsize = 11,
             arrowprops = dict(arrowstyle = '->',connectionstyle = 'arc3,rad = .2'))


plt.xticks(L, fontsize=12)
plt.yticks(fontsize=12)
plt.xlabel('L', fontsize=12)
plt.ylabel('Pr(find the nearest neighbor)', fontsize=12)


plt.twinx()
plt.plot(L, nearest_time, marker='>', c='b',  linestyle='dashed', label='total query time',)
plt.plot(L, time, marker='v', c='darkblue', linestyle='dashed', label='hashing time')
# plt.plot(M, std_precision,  marker='x', c='dodgerblue', linestyle='dashed', label='precision')

plt.yticks(fontsize=12)
plt.ylabel('time(ms)', fontsize=12)
plt.legend(loc=7, fontsize=12)

plt.subplots_adjust(top=0.950,
bottom=0.135,
left=0.18,
right=0.85,
hspace=0.2,
wspace=0.2)
plt.savefig('./img/k=2-m=1-3.png',dpi=1500)
plt.show()

# %%
plt.figure(figsize=(5, 4))
plt.plot(L, candidate, marker='o', c='r')
plt.grid()
plt.annotate('number of candidates',
             xy=(L[2],candidate[2]), xycoords = 'data', xytext= (-120,+10),
             textcoords= 'offset points',
             fontsize = 12,
             arrowprops = dict(arrowstyle = '->',connectionstyle = 'arc3,rad = .2'))


plt.xticks(L, fontsize=12)
plt.yticks(fontsize=12)
plt.xlabel('L', fontsize=12)
plt.ylabel('number of candidates', fontsize=12)


plt.twinx()
plt.plot(L, nearest_time, marker='>', c='b',  linestyle='dashed', label='total query time',)
plt.plot(L, time, marker='v', c='darkblue', linestyle='dashed', label='hashing time')
# plt.plot(M, std_precision,  marker='x', c='dodgerblue', linestyle='dashed', label='precision')

plt.yticks(fontsize=12)
plt.ylabel('time(ms)', fontsize=12)
plt.legend(loc=7, fontsize=12)

plt.subplots_adjust(top=0.950,
bottom=0.135,
left=0.18,
right=0.85,
hspace=0.2,
wspace=0.2)
plt.savefig('./img/k=2-m=1-4.png',dpi=1500)
plt.show()

# %% [markdown]
# ## k = 4, L = 10, m from 1 to 8

# %%
M = [1, 2, 3, 4, 5, 6, 7, 8]
precision = [0.47, 0.65, 0.79, 0.86, 0.91, 0.93, 0.93, 0.93]
std_precision = [0.95, 0.93, 0.92, 0.91, 0.90, 0.89, 0.88, 0.8745]
recall = [0.23, 0.34, 0.41, 0.47, 0.507, 0.53, 0.56, 0.58]
f1 = [0.38, 0.5, 0.57, 0.62, 0.649, 0.67, 0.687, 0.6928]
time = [5, 7, 8, 10, 12, 14, 15, 17.34]
nearest_time = [10, 14, 17, 20, 23, 26, 28, 31]
candidate = [220, 320, 399, 461, 502, 535, 565, 594]

# %% [markdown]
# ### 找到最近邻的概率和 m 的关系

# %%
plt.figure(figsize=(5, 4))
plt.xlabel('m', fontsize=12)
plt.plot(M, precision, marker='o', c='r')
plt.ylabel('probability of find the nearest neighbor', fontsize=11)
plt.grid()
plt.annotate('Pr(find the nearest neighbor)',
             xy=(M[4],precision[4]), xycoords = 'data', xytext= (-120,+10),
             textcoords= 'offset points',
             fontsize = 12,
             arrowprops = dict(arrowstyle = '->',connectionstyle = 'arc3,rad = .2'))
plt.twinx()
plt.plot(M, recall, marker='v', linestyle='dashed', c='darkblue', label='recall')
plt.plot(M, f1, marker='>', label='F1', c='b',  linestyle='dashed')
plt.plot(M, std_precision, linestyle='dashed', marker='x', c='dodgerblue', label='precision')
plt.ylabel('precision \ recall \ F1', fontsize=12)
plt.legend(fontsize=12)
plt.show()
plt.savefig('./img/k=4-L=10-1', dpi=350)
# plt.grid()
# ax2.set_ylabel('Y values for ln(x)')
# ax2.set_xlabel('Same X for both exp(-x) and ln(x)')

# %% [markdown]
# ### 候选集和m的关系，以及和其他指标的关系

# %%
plt.figure(figsize=(5, 4))
plt.xlabel('m', fontsize=12)
plt.plot(M, candidate, marker='o', c='r')
plt.ylabel('number of candidates', fontsize=11)
plt.grid()
plt.annotate('number of candidates',
             xy=(M[4],candidate[4]), xycoords = 'data', xytext= (-130,+30),
             textcoords= 'offset points',
             fontsize = 11,
             arrowprops = dict(arrowstyle = '->',connectionstyle = 'arc3,rad = .2'))
plt.twinx()
plt.plot(M, recall, marker='v', linestyle='dashed', c='darkblue', label='recall')
plt.plot(M, f1, marker='>', label='F1', c='b',  linestyle='dashed')
plt.plot(M, std_precision, linestyle='dashed', marker='x', c='dodgerblue', label='precision')
plt.ylabel('precision \ recall \ F1', fontsize=11)
plt.legend(fontsize=11)
plt.show()
# plt.grid()
# ax2.set_ylabel('Y values for ln(x)')
# ax2.set_xlabel('Same X for both exp(-x) and ln(x)')

# %% [markdown]
# ### 找到最近邻的概率和查询时间的关系

# %%
plt.figure(figsize=(5, 4))
plt.xlabel('m', fontsize=12)
plt.plot(M, precision, marker='o', c='r')
plt.ylabel('probability of find the nearest neighbor', fontsize=11)
plt.grid()
plt.annotate('Pr(find the nearest neighbor)',
             xy=(M[4],precision[4]), xycoords = 'data', xytext= (-120,+10),
             textcoords= 'offset points',
             fontsize = 11,
             arrowprops = dict(arrowstyle = '->',connectionstyle = 'arc3,rad = .2'))
plt.twinx()
plt.plot(M, nearest_time, marker='>', c='b',  linestyle='dashed', label='total query time',)
plt.plot(M, time, marker='v', c='darkblue', linestyle='dashed', label='hashing time')
# plt.plot(M, std_precision,  marker='x', c='dodgerblue', linestyle='dashed', label='precision')
plt.ylabel('time(ms)', fontsize=11)
plt.legend(loc=7, fontsize=11)
plt.show()

# %% [markdown]
# ### 候选集和查询时间的关系

# %%
plt.figure(figsize=(5, 4))
plt.xlabel('m', fontsize=12)
plt.plot(M, candidate, marker='o', c='r')
plt.ylabel('number of candidates', fontsize=11)
plt.grid()
plt.annotate('number of candidates',
             xy=(M[4],candidate[4]), xycoords = 'data', xytext= (-140,+10),
             textcoords= 'offset points',
             fontsize = 11,
             arrowprops = dict(arrowstyle = '->',connectionstyle = 'arc3,rad = .2'))
plt.twinx()
plt.plot(M, nearest_time, marker='>', c='b',  linestyle='dashed', label='total query time',)
plt.plot(M, time, marker='v', c='darkblue', linestyle='dashed', label='hashing time')
# plt.plot(M, std_precision,  marker='x', c='dodgerblue', linestyle='dashed', label='precision')
plt.ylabel('time(ms)', fontsize=11)
plt.legend(loc=7, fontsize=11)
plt.show()

# %% [markdown]
# ## k = 4, m = 1

# %%
L = [10, 20, 30, 40, 50]
precision = [0.47, 0.7, 0.81, 0.92, 0.95]
std_precision = [0.95, 0.9373, 0.9356, 0.9324, 0.9308]
recall = [0.23, 0.3617, 0.5042, 0.63, 0.65]
f1 = [0.38, 0.5220, 0.655, 0.75, 0.76]
time = [5, 9.7, 15, 19, 22]
nearest_time = [10, 17, 23, 30, 38]
candidate = [220, 342, 480, 605, 627]

# %% [markdown]
# ## L = 10, k = 2 / 4, m = 1, 2, ..., 8

# %%
M = [1, 2, 3, 4, 5, 6, 7, 8]

precision1 = [0.71, 0.88, 0.91, 0.94, 0.98, 0.98, 0.98, 1]
std_precision1 = [0.797, 0.7482, 0.7054, 0.66, 0.63, 0.6, 0.57, 0.55]
recall1 = [0.4573, 0.5946, 0.6791, 0.73, 0.767, 0.79, 0.81, 0.84]
f11 = [0.5812, 0.6625, 0.693, 0.6959, 0.6948, 0.68, 0.67, 0.66]
time1 = [6, 6, 7, 9, 10.8, 12, 13, 15.21]
nearest_time1 = [16, 20, 28, 30, 36, 38, 45, 47.36]
candidate1 = [522, 726, 884, 1014, 1106, 1200, 1296, 1392]

precision2 = [0.47, 0.65, 0.79, 0.86, 0.91, 0.93, 0.93, 0.93]
std_precision2 = [0.95, 0.93, 0.92, 0.91, 0.90, 0.89, 0.88, 0.8745]
recall2 = [0.23, 0.34, 0.41, 0.47, 0.507, 0.53, 0.56, 0.58]
f12 = [0.38, 0.5, 0.57, 0.62, 0.649, 0.67, 0.687, 0.6928]
time2 = [5, 7, 8, 10, 12, 14, 15, 17.34]
nearest_time2 = [10, 14, 17, 20, 23, 26, 28, 31]
candidate2 = [220, 320, 399, 461, 502, 535, 565, 594]

# %%
plt.figure(figsize=(5, 4))
plt.plot(M, precision1, marker='o', c='r', label='k=2')
plt.annotate('k=2',
             xy=(M[3],precision1[3]), xycoords = 'data', xytext= (-40,+10),
             textcoords= 'offset points',
             fontsize = 12,
             arrowprops = dict(arrowstyle = '->',connectionstyle = 'arc3,rad = .2'))

plt.plot(M, precision2, marker='>', c='b', label='k=4')
plt.annotate('k=4',
             xy=(M[2],precision2[2]), xycoords = 'data', xytext= (+30,-10),
             textcoords= 'offset points',
             fontsize = 12,
             arrowprops = dict(arrowstyle = '->',connectionstyle = 'arc3,rad = .2'))

plt.xticks(M, fontsize=12)
plt.yticks(fontsize=12)
plt.xlabel('m (probe factor)', fontsize=12)
plt.ylabel('Pr(find the nearest neighbor)', fontsize=12)
plt.legend(fontsize=12, loc=4)

plt.subplots_adjust(top=0.950,
bottom=0.135,
left=0.15,
right=0.95,
hspace=0.2,
wspace=0.2)
plt.grid()
plt.savefig('./img/L=10-k=2-1.png',dpi=1500)
plt.show()

# %%
plt.figure(figsize=(5, 4))

plt.plot(M, std_precision1, marker='o', c='r', label='k=2')
plt.plot(M, std_precision2, marker='>', c='b', label='k=4')
plt.annotate('precision',
             xy=(M[2],std_precision2[2]), xycoords = 'data', xytext= (-60,-30),
             textcoords= 'offset points',
             fontsize = 12,
             arrowprops = dict(arrowstyle = '->',connectionstyle = 'arc3,rad = .2'))

plt.xlabel('m', fontsize=12)
plt.ylabel('precision', fontsize=12)
plt.grid()
plt.legend(fontsize=12, loc=3)
plt.xticks(fontsize=12)

plt.twinx()
plt.plot(M, recall1, marker='o', c='r',  linestyle='dashed', label='k=2',)
plt.plot(M, recall2, marker='>', c='b', linestyle='dashed', label='k=4')
plt.annotate('recall',
             xy=(M[4],recall2[4]), xycoords = 'data', xytext= (+30,-20),
             textcoords= 'offset points',
             fontsize = 12,
             arrowprops = dict(arrowstyle = '->',connectionstyle = 'arc3,rad = .2'))

plt.yticks(fontsize=12)
plt.ylabel('recall', fontsize=12)

plt.subplots_adjust(top=0.950,
bottom=0.135,
left=0.18,
right=0.85,
hspace=0.2,
wspace=0.2)
plt.savefig('./img/L=10-k=2-2.png',dpi=1500)
plt.show()

# %%
plt.figure(figsize=(5, 4))
plt.plot(M, f11, marker='o', c='r', label='k=2')
plt.plot(M, f12, marker='>', c='b', label='k=4')

plt.xticks(M, fontsize=12)
plt.yticks(fontsize=12)
plt.xlabel('m', fontsize=12)
plt.ylabel('F1', fontsize=12)
plt.legend(fontsize=12, loc=4)

plt.subplots_adjust(top=0.950,
bottom=0.135,
left=0.15,
right=0.95,
hspace=0.2,
wspace=0.2)
plt.grid()
plt.savefig('./img/L=10-k=2-3.png',dpi=1500)
plt.show()

# %%
plt.figure(figsize=(5, 4))

plt.plot(M, nearest_time1, marker='o', c='r', label='k=2')
plt.plot(M, nearest_time2, marker='>', c='b', label='k=4')
plt.plot(M, time1, marker='o', c='r',  linestyle='dashed')
plt.plot(M, time2, marker='>', c='b', linestyle='dashed')

plt.annotate('total time',
             xy=(M[3],nearest_time1[3]), xycoords = 'data', xytext= (+20,-10),
             textcoords= 'offset points',
             fontsize = 12,
             arrowprops = dict(arrowstyle = '->',connectionstyle = 'arc3,rad = .2'))
plt.annotate('hashing time',
             xy=(M[5],time1[5]), xycoords = 'data', xytext= (-10,-30),
             textcoords= 'offset points',
             fontsize = 12,
             arrowprops = dict(arrowstyle = '->',connectionstyle = 'arc3,rad = .2'))

plt.xticks(fontsize=12)
plt.xlabel('m', fontsize=12)
plt.ylabel('time(ms)', fontsize=12)
plt.grid()
plt.legend(fontsize=12, loc=2)

plt.twinx()
plt.plot(M, candidate1, marker='o', c='r', linestyle='dotted')
plt.plot(M, candidate2, marker='>', c='b', linestyle='dotted')
plt.annotate('candidate',
             xy=(M[5],candidate1[5]), xycoords = 'data', xytext= (-50,+20),
             textcoords= 'offset points',
             fontsize = 12,
             arrowprops = dict(arrowstyle = '->',connectionstyle = 'arc3,rad = .2'))

plt.yticks(fontsize=10)
plt.ylabel('number of candidates', fontsize=12)

plt.subplots_adjust(top=0.950,
bottom=0.135,
left=0.18,
right=0.85,
hspace=0.2,
wspace=0.2)
plt.savefig('./img/L=10-k=2-4.png',dpi=1500)
plt.show()

# %% [markdown]
# # MNIST

# %%
x = np.arange(4)
money = [1.5e5, 2.5e6, 5.5e6, 2.0e7]


def millions(x, pos):
    'The two args are the value and tick position'
    return '$%1.1fM' % (x * 1e-6)


formatter = FuncFormatter(millions)

fig, ax = plt.subplots()
ax.yaxis.set_major_formatter(formatter)
plt.bar(x, money)
plt.xticks(x, ('Bill', 'Fred', 'Mary', 'Sue'))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-41-77a9dbd78494> in <module>()
#       8
#       9
# ---> 10 formatter = FuncFormatter(millions)
#      11
#      12 fig, ax = plt.subplots()
#
# NameError: name 'FuncFormatter' is not defined

# %%
plt.figure(figsize=(5, 4))

data = [107, 90, 193, 160, 292.7, 917]
methods = ['OPRCP', 'TLOPRCP', 'TLBHL', 'BHL', 'TLE2LSH', 'Linear Search']
colors = ['r', 'tomato', 'slategrey', 'dimgrey', 'grey', 'b']
x = np.arange(6)
for idx, v in enumerate(data):
    plt.bar(idx, v, label=methods[idx], color=colors[idx], width=0.6)

plt.legend(fontsize=12)
plt.xticks([])
plt.yticks(fontsize=11)
plt.xlabel('methods', fontsize=12)
plt.ylabel('query time(ms)', fontsize=12)

plt.subplots_adjust(top=0.950,
bottom=0.135,
left=0.15,
right=0.95,
hspace=0.2,
wspace=0.2)
# plt.grid()
plt.savefig('./img/mnist-nearest-time.png',dpi=1500)
plt.show()

# %%
plt.figure(figsize=(5, 4))

data = [50, 11, 107, 60, 44.7]
methods = ['OPRCP', 'TLOPRCP', 'TLBHL', 'BHL', 'TLE2LSH']
colors = ['r', 'tomato', 'slategrey', 'dimgrey', 'grey']
x = np.arange(6)
for idx, v in enumerate(data):
    plt.bar(idx, v, label=methods[idx], color=colors[idx], width=0.6)

plt.legend(fontsize=12, loc=2)
plt.xticks([])
plt.yticks(fontsize=11)
plt.xlabel('methods', fontsize=12)
plt.ylabel('hashing time(ms)', fontsize=12)

plt.subplots_adjust(top=0.950,
bottom=0.135,
left=0.15,
right=0.95,
hspace=0.2,
wspace=0.2)
# plt.grid()
plt.savefig('./img/mnist-hashing-time.png',dpi=1500)
plt.show()

# %%
plt.figure(figsize=(5, 4))

data = [0.3, 0.259, 0.25, 0.179, 0.0919]
methods = ['OPRCP', 'TLOPRCP', 'TLBHL', 'BHL', 'TLE2LSH']
colors = ['r', 'tomato', 'slategrey', 'dimgrey', 'grey']
x = np.arange(6)
for idx, v in enumerate(data):
    plt.bar(idx, v, label=methods[idx], color=colors[idx], width=0.6)

plt.legend(fontsize=12, loc=1)
plt.xticks([])
plt.yticks(fontsize=11)
plt.xlabel('methods', fontsize=12)
plt.ylabel('F1', fontsize=12)

plt.subplots_adjust(top=0.950,
bottom=0.135,
left=0.15,
right=0.95,
hspace=0.2,
wspace=0.2)
# plt.grid()
plt.savefig('./img/mnist-F1.png',dpi=1500)
plt.show()

# %%
plt.figure(figsize=(5, 4))

data = [1950, 3220, 5421, 5458, 15000]
methods = ['OPRCP', 'TLOPRCP', 'TLBHL', 'BHL', 'TLE2LSH']
colors = ['r', 'tomato', 'slategrey', 'dimgrey', 'grey']
x = np.arange(6)
for idx, v in enumerate(data):
    plt.bar(idx, v, label=methods[idx], color=colors[idx], width=0.6)

plt.legend(fontsize=12)
plt.xticks([])
plt.yticks(fontsize=11)
plt.xlabel('methods', fontsize=12)
plt.ylabel('candidates', fontsize=12)

plt.subplots_adjust(top=0.950,
bottom=0.135,
left=0.15,
right=0.95,
hspace=0.2,
wspace=0.2)
# plt.grid()
plt.savefig('./img/mnist-candidates.png',dpi=1500)
plt.show()

# %%
plt.figure(figsize=(5, 4))

data = [64, 14.24, 734, 1906, 2033]
methods = ['OPRCP', 'TLOPRCP', 'TLBHL', 'BHL', 'TLE2LSH']
colors = ['r', 'tomato', 'slategrey', 'dimgrey', 'grey']
x = np.arange(6)
for idx, v in enumerate(data):
    plt.bar(idx, v, label=methods[idx], color=colors[idx], width=0.6)

plt.legend(fontsize=12)
plt.xticks([])
plt.yticks(fontsize=11)
plt.xlabel('methods', fontsize=12)
plt.ylabel('memory(MB)', fontsize=12)

plt.subplots_adjust(top=0.950,
bottom=0.135,
left=0.15,
right=0.95,
hspace=0.2,
wspace=0.2)
# plt.grid()
plt.savefig('./img/mnist-memory.png',dpi=1500)
plt.show()

# %%
plt.figure(figsize=(5, 4))

data = [0.2, 0.156, 0.15, 0.0988, 0.048]
methods = ['OPRCP', 'TLOPRCP', 'TLBHL', 'BHL', 'TLE2LSH']
colors = ['r', 'tomato', 'slategrey', 'dimgrey', 'grey']
x = np.arange(6)
for idx, v in enumerate(data):
    plt.bar(idx, v, label=methods[idx], color=colors[idx], width=0.6)

plt.legend(fontsize=12, loc=1)
plt.xticks([])
plt.yticks(fontsize=11)
plt.xlabel('methods', fontsize=12)
plt.ylabel('precision', fontsize=12)

plt.subplots_adjust(top=0.950,
bottom=0.135,
left=0.15,
right=0.95,
hspace=0.2,
wspace=0.2)
# plt.grid()
plt.savefig('./img/mnist-precision.png',dpi=1500)
plt.show()

# %%
plt.figure(figsize=(5, 4))

data = [0.62, 0.89, 0.936, 0.96, 0.942]
methods = ['OPRCP', 'TLOPRCP', 'TLBHL', 'BHL', 'TLE2LSH']
colors = ['r', 'tomato', 'slategrey', 'dimgrey', 'grey']
x = np.arange(6)
for idx, v in enumerate(data):
    plt.bar(idx, v, label=methods[idx], color=colors[idx], width=0.6)

plt.legend(fontsize=11, loc=4)
plt.xticks([])
plt.yticks(fontsize=11)
plt.xlabel('methods', fontsize=12)
plt.ylabel('recall', fontsize=12)

plt.subplots_adjust(top=0.950,
bottom=0.135,
left=0.15,
right=0.95,
hspace=0.2,
wspace=0.2)
# plt.grid()
plt.savefig('./img/mnist-recall.png',dpi=1500)
plt.show()
